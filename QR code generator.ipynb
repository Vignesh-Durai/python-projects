# %% [markdown]
# ## QR code generator

# %%
# install QR code

# %%
pip install qrcode
# Out:
# Requirement already satisfied: qrcode in c:\users\vigne\anaconda3\lib\site-packages (8.2)
# Requirement already satisfied: colorama in c:\users\vigne\anaconda3\lib\site-packages (from qrcode) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import dependent libraries
import qrcode
from IPython.display import display
from PIL import Image

# %%
data=input("Enter the required url: ")
file_name=input("Enter the file name: ")
qr=qrcode.QRCode(box_size=10,border=4)
qr.add_data(data)
image=qr.make_image(fill_color="black",back_color="white")
image.save(file_name)
display(image)
print(f"here we go with your QR code :{file_name} scan the QR code and enjoy")
# Out:
# Enter the required url:  https://vicky-13.neocities.org/EMC/
# Enter the file name:  vicky.jpg
# here we go with your QR code :vicky.jpg scan the QR code and enjoy
